# %% [markdown]
# ### Comparison of final outcomes
#
# This allows to get an idea of the concrete consequences of a system transition from R to Python. These have been calculated for the year 2023, using the results available at the time of the review, i.e. forecasts issued between May and October 2023.

# %%
import numpy as np
import pandas as pd

import warnings
warnings.filterwarnings('ignore')

# %cd ../
# Out:
# c:\Users\amine.barkaoui\OneDrive - World Food Programme\Documents\GitHub\anticipatory-action

# %%
df_merged = pd.read_csv(f"data/MOZ/outputs/Fbf_Pilot_MockUp/Python_probabilities_season_triggers.csv").dropna()

# %%
# Keep SPI by default and DRYSPELL when not available
df_merged = pd.concat([
    wcd.sort_values('index', ascending=False).head(4)
    for (w, c, d), wcd in df_merged.groupby(['district', 'category', 'Window'])
])

# %% [markdown]
# ### Python outcomes

# %%
df_merged.loc[df_merged.trigger == 'trigger2', 'issue'] = df_merged.loc[df_merged.trigger == 'trigger2'].issue.values - 1

# %%
for (d, c, w, ind, iss), pair in df_merged.groupby(['district', 'category', 'Window', 'index', 'issue']):
    activations = pair.sort_values('trigger').prob > pair.sort_values('trigger').trigger_value
    if len(activations) == 1:
        state = 'Ready' * int(activations.iloc[0]) + 'NA' * (1 - int(activations.iloc[0]))
    else:
        state = 'Set' if activations.all() else 'NA'
    df_merged.loc[
        (df_merged.district == d) & (df_merged.Window == w) & (df_merged['index'] == ind) & (df_merged.issue == iss), 'state'
    ] = state

# %%
outcomes = pd.DataFrame(columns=["W1-Leve", "W1-Moderado", "W1-Severo", "W2-Leve", "W2-Moderado", "W2-Severo"], index = df_merged['district'].sort_values().unique())
for d, r in outcomes.iterrows():
    val = []
    for w in df_merged['Window'].unique():
        for c in df_merged['category'].unique():
                val.append(df_merged[(df_merged['Window']==w) & (df_merged['category']==c) & (df_merged['district']==d)].state.max())   
    outcomes.loc[d] = val

# %%
outcomes.style.format(na_rep="missing so far")
# Out:
# <style type="text/css">
# </style>
# <table id="T_00729">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_00729_level0_col0" class="col_heading level0 col0" >W1-Leve</th>
#       <th id="T_00729_level0_col1" class="col_heading level0 col1" >W1-Moderado</th>
#       <th id="T_00729_level0_col2" class="col_heading level0 col2" >W1-Severo</th>
#       <th id="T_00729_level0_col3" class="col_heading level0 col3" >W2-Leve</th>
#       <th id="T_00729_level0_col4" class="col_heading level0 col4" >W2-Moderado</th>
#       <th id="T_00729_level0_col5" class="col_heading level0 col5" >W2-Severo</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_00729_level0_row0" class="row_heading level0 row0" >Caia</th>
#       <td id="T_00729_row0_col0" class="data row0 col0" >NA</td>
#       <td id="T_00729_row0_col1" class="data row0 col1" >NA</td>
#       <td id="T_00729_row0_col2" class="data row0 col2" >NA</td>
#       <td id="T_00729_row0_col3" class="data row0 col3" >Ready</td>
#       <td id="T_00729_row0_col4" class="data row0 col4" >missing so far</td>
#       <td id="T_00729_row0_col5" class="data row0 col5" >missing so far</td>
#     </tr>
#     <tr>
#       <th id="T_00729_level0_row1" class="row_heading level0 row1" >Changara</th>
#       <td id="T_00729_row1_col0" class="data row1 col0" >Set</td>
#       <td id="T_00729_row1_col1" class="data row1 col1" >Set</td>
#       <td id="T_00729_row1_col2" class="data row1 col2" >NA</td>
#       <td id="T_00729_row1_col3" class="data row1 col3" >NA</td>
#       <td id="T_00729_row1_col4" class="data row1 col4" >NA</td>
#       <td id="T_00729_row1_col5" class="data row1 col5" >NA</td>
#     </tr>
#     <tr>
#       <th id="T_00729_level0_row2" class="row_heading level0 row2" >Chemba</th>
#       <td id="T_00729_row2_col0" class="data row2 col0" >NA</td>
#       <td id="T_00729_row2_col1" class="data row2 col1" >NA</td>
#       <td id="T_00729_row2_col2" class="data row2 col2" >NA</td>
#       <td id="T_00729_row2_col3" class="data row2 col3" >Ready</td>
#       <td id="T_00729_row2_col4" class="data row2 col4" >Ready</td>
#       <td id="T_00729_row2_col5" class="data row2 col5" >missing so far</td>
#     </tr>
#     <tr>
#       <th id="T_00729_level0_row3" class="row_heading level0 row3" >Chibuto</th>
#       <td id="T_00729_row3_col0" class="data row3 col0" >Set</td>
#       <td id="T_00729_row3_col1" class="data row3 col1" >Set</td>
#       <td id="T_00729_row3_col2" class="data row3 col2" >missing so far</td>
#       <td id="T_00729_row3_col3" class="data row3 col3" >Set</td>
#       <td id="T_00729_row3_col4" class="data row3 col4" >Ready</td>
#       <td id="T_00729_row3_col5" class="data row3 col5" >Set</td>
#     </tr>
#     <tr>
#       <th id="T_00729_level0_row4" class="row_heading level0 row4" >Chicualacuala</th>
#       <td id="T_00729_row4_col0" class="data row4 col0" >Set</td>
#       <td id="T_00729_row4_col1" class="data row4 col1" >NA</td>
#       <td id="T_00729_row4_col2" class="data row4 col2" >NA</td>
#       <td id="T_00729_row4_col3" class="data row4 col3" >NA</td>
#       <td id="T_00729_row4_col4" class="data row4 col4" >missing so far</td>
#       <td id="T_00729_row4_col5" class="data row4 col5" >NA</td>
#     </tr>
#     <tr>
#       <th id="T_00729_level0_row5" class="row_heading level0 row5" >Chiure</th>
#       <td id="T_00729_row5_col0" class="data row5 col0" >NA</td>
#       <td id="T_00729_row5_col1" class="data row5 col1" >NA</td>
#       <td id="T_00729_row5_col2" class="data row5 col2" >NA</td>
#       <td id="T_00729_row5_col3" class="data row5 col3" >NA</td>
#       <td id="T_00729_row5_col4" class="data row5 col4" >missing so far</td>
#       <td id="T_00729_row5_col5" class="data row5 col5" >NA</td>
#     </tr>
#     <tr>
#       <th id="T_00729_level0_row6" class="row_heading level0 row6" >Guija</th>
#       <td id="T_00729_row6_col0" class="data row6 col0" >NA</td>
#       <td id="T_00729_row6_col1" class="data row6 col1" >NA</td>
#       <td id="T_00729_row6_col2" class="data row6 col2" >NA</td>
#       <td id="T_00729_row6_col3" class="data row6 col3" >Set</td>
#       <td id="T_00729_row6_col4" class="data row6 col4" >NA</td>
#       <td id="T_00729_row6_col5" class="data row6 col5" >missing so far</td>
#     </tr>
#     <tr>
#       <th id="T_00729_level0_row7" class="row_heading level0 row7" >Mabalane</th>
#       <td id="T_00729_row7_col0" class="data row7 col0" >Set</td>
#       <td id="T_00729_row7_col1" class="data row7 col1" >NA</td>
#       <td id="T_00729_row7_col2" class="data row7 col2" >NA</td>
#       <td id="T_00729_row7_col3" class="data row7 col3" >Set</td>
#       <td id="T_00729_row7_col4" class="data row7 col4" >Ready</td>
#       <td id="T_00729_row7_col5" class="data row7 col5" >Set</td>
#     </tr>
#     <tr>
#       <th id="T_00729_level0_row8" class="row_heading level0 row8" >Mapai</th>
#       <td id="T_00729_row8_col0" class="data row8 col0" >Set</td>
#       <td id="T_00729_row8_col1" class="data row8 col1" >Set</td>
#       <td id="T_00729_row8_col2" class="data row8 col2" >Set</td>
#       <td id="T_00729_row8_col3" class="data row8 col3" >Ready</td>
#       <td id="T_00729_row8_col4" class="data row8 col4" >Ready</td>
#       <td id="T_00729_row8_col5" class="data row8 col5" >NA</td>
#     </tr>
#     <tr>
#       <th id="T_00729_level0_row9" class="row_heading level0 row9" >Marara</th>
#       <td id="T_00729_row9_col0" class="data row9 col0" >NA</td>
#       <td id="T_00729_row9_col1" class="data row9 col1" >Set</td>
#       <td id="T_00729_row9_col2" class="data row9 col2" >Set</td>
#       <td id="T_00729_row9_col3" class="data row9 col3" >NA</td>
#       <td id="T_00729_row9_col4" class="data row9 col4" >missing so far</td>
#       <td id="T_00729_row9_col5" class="data row9 col5" >missing so far</td>
#     </tr>
#     <tr>
#       <th id="T_00729_level0_row10" class="row_heading level0 row10" >Massingir</th>
#       <td id="T_00729_row10_col0" class="data row10 col0" >NA</td>
#       <td id="T_00729_row10_col1" class="data row10 col1" >Set</td>
#       <td id="T_00729_row10_col2" class="data row10 col2" >NA</td>
#       <td id="T_00729_row10_col3" class="data row10 col3" >Set</td>
#       <td id="T_00729_row10_col4" class="data row10 col4" >Set</td>
#       <td id="T_00729_row10_col5" class="data row10 col5" >NA</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ### R outcomes

# %%
ref = pd.read_csv(f"AA/data/MOZ/outputs/Fbf_Pilot_MockUp/R_probabilities_season_triggers.csv").dropna()
ref.loc[ref.Trigger_nb == 'trigger2', 'Month'] = ref.loc[ref.Trigger_nb == 'trigger2'].Month.values - 1

# %%
for (d, c, w, ind, iss), pair in ref.groupby(['District', 'Category', 'Windows', 'Index', 'Month']):
    activations = pair.sort_values('Trigger_nb').Probability > pair.sort_values('Trigger_nb').Trigger
    if len(activations) == 1:
        state = 'Ready' * int(activations.iloc[0]) + 'NA' * (1 - int(activations.iloc[0]))
    else:
        state = 'Set' if activations.all() else 'NA'
    ref.loc[
        (ref.District == d) & (ref.Category == c) & (ref.Windows == w) & (ref['Index'] == ind) & (ref.Month == iss), 'state'
    ] = state
# Out:
# C:\Users\amine.barkaoui\AppData\Local\Temp\ipykernel_9024\728995433.py:7: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value 'Set' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   ref.loc[

# %%
outcomes_R = pd.DataFrame(columns=["W1-Leve", "W1-Moderado", "W1-Severo", "W2-Leve", "W2-Moderado", "W2-Severo"], index = ref['District'].sort_values().unique())
for d, r in outcomes_R.iterrows():
    val = []
    for w in ref['Windows'].unique():
        for c in ref['Category'].unique():
                val.append(ref[(ref['Windows']==w) & (ref['Category']==c) & (ref['District']==d)].state.max())   
    outcomes_R.loc[d] = val

# %%
outcomes_R.style.format(na_rep="missing so far")
# Out:
# <style type="text/css">
# #T_ebcc6_row0_col0, #T_ebcc6_row0_col1, #T_ebcc6_row0_col2, #T_ebcc6_row0_col3, #T_ebcc6_row0_col4, #T_ebcc6_row0_col5, #T_ebcc6_row1_col0, #T_ebcc6_row1_col1, #T_ebcc6_row1_col2, #T_ebcc6_row1_col3, #T_ebcc6_row1_col4, #T_ebcc6_row1_col5, #T_ebcc6_row2_col0, #T_ebcc6_row2_col1, #T_ebcc6_row2_col2, #T_ebcc6_row2_col3, #T_ebcc6_row2_col4, #T_ebcc6_row2_col5, #T_ebcc6_row3_col0, #T_ebcc6_row3_col1, #T_ebcc6_row3_col2, #T_ebcc6_row3_col3, #T_ebcc6_row3_col4, #T_ebcc6_row3_col5, #T_ebcc6_row4_col0, #T_ebcc6_row4_col1, #T_ebcc6_row4_col2, #T_ebcc6_row4_col3, #T_ebcc6_row4_col4, #T_ebcc6_row4_col5, #T_ebcc6_row5_col0, #T_ebcc6_row5_col1, #T_ebcc6_row5_col2, #T_ebcc6_row5_col3, #T_ebcc6_row5_col4, #T_ebcc6_row5_col5, #T_ebcc6_row6_col0, #T_ebcc6_row6_col1, #T_ebcc6_row6_col2, #T_ebcc6_row6_col3, #T_ebcc6_row6_col4, #T_ebcc6_row6_col5, #T_ebcc6_row7_col0, #T_ebcc6_row7_col1, #T_ebcc6_row7_col2, #T_ebcc6_row7_col3, #T_ebcc6_row7_col4, #T_ebcc6_row7_col5, #T_ebcc6_row8_col0, #T_ebcc6_row8_col1, #T_ebcc6_row8_col2, #T_ebcc6_row8_col3, #T_ebcc6_row8_col4, #T_ebcc6_row8_col5, #T_ebcc6_row9_col0, #T_ebcc6_row9_col1, #T_ebcc6_row9_col2, #T_ebcc6_row9_col3, #T_ebcc6_row9_col4, #T_ebcc6_row9_col5, #T_ebcc6_row10_col0, #T_ebcc6_row10_col1, #T_ebcc6_row10_col2, #T_ebcc6_row10_col3, #T_ebcc6_row10_col4, #T_ebcc6_row10_col5, #T_ebcc6_row11_col0, #T_ebcc6_row11_col1, #T_ebcc6_row11_col2, #T_ebcc6_row11_col3, #T_ebcc6_row11_col4, #T_ebcc6_row11_col5 {
#   background-color: ;
# }
# </style>
# <table id="T_ebcc6">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_ebcc6_level0_col0" class="col_heading level0 col0" >W1-Leve</th>
#       <th id="T_ebcc6_level0_col1" class="col_heading level0 col1" >W1-Moderado</th>
#       <th id="T_ebcc6_level0_col2" class="col_heading level0 col2" >W1-Severo</th>
#       <th id="T_ebcc6_level0_col3" class="col_heading level0 col3" >W2-Leve</th>
#       <th id="T_ebcc6_level0_col4" class="col_heading level0 col4" >W2-Moderado</th>
#       <th id="T_ebcc6_level0_col5" class="col_heading level0 col5" >W2-Severo</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_ebcc6_level0_row0" class="row_heading level0 row0" >Caia</th>
#       <td id="T_ebcc6_row0_col0" class="data row0 col0" >NA</td>
#       <td id="T_ebcc6_row0_col1" class="data row0 col1" >Set</td>
#       <td id="T_ebcc6_row0_col2" class="data row0 col2" >Set</td>
#       <td id="T_ebcc6_row0_col3" class="data row0 col3" >Ready</td>
#       <td id="T_ebcc6_row0_col4" class="data row0 col4" >NA</td>
#       <td id="T_ebcc6_row0_col5" class="data row0 col5" >Ready</td>
#     </tr>
#     <tr>
#       <th id="T_ebcc6_level0_row1" class="row_heading level0 row1" >Changara</th>
#       <td id="T_ebcc6_row1_col0" class="data row1 col0" >NA</td>
#       <td id="T_ebcc6_row1_col1" class="data row1 col1" >NA</td>
#       <td id="T_ebcc6_row1_col2" class="data row1 col2" >NA</td>
#       <td id="T_ebcc6_row1_col3" class="data row1 col3" >missing so far</td>
#       <td id="T_ebcc6_row1_col4" class="data row1 col4" >missing so far</td>
#       <td id="T_ebcc6_row1_col5" class="data row1 col5" >missing so far</td>
#     </tr>
#     <tr>
#       <th id="T_ebcc6_level0_row2" class="row_heading level0 row2" >Chemba</th>
#       <td id="T_ebcc6_row2_col0" class="data row2 col0" >NA</td>
#       <td id="T_ebcc6_row2_col1" class="data row2 col1" >NA</td>
#       <td id="T_ebcc6_row2_col2" class="data row2 col2" >NA</td>
#       <td id="T_ebcc6_row2_col3" class="data row2 col3" >Ready</td>
#       <td id="T_ebcc6_row2_col4" class="data row2 col4" >NA</td>
#       <td id="T_ebcc6_row2_col5" class="data row2 col5" >Ready</td>
#     </tr>
#     <tr>
#       <th id="T_ebcc6_level0_row3" class="row_heading level0 row3" >Chibuto</th>
#       <td id="T_ebcc6_row3_col0" class="data row3 col0" >NA</td>
#       <td id="T_ebcc6_row3_col1" class="data row3 col1" >Set</td>
#       <td id="T_ebcc6_row3_col2" class="data row3 col2" >NA</td>
#       <td id="T_ebcc6_row3_col3" class="data row3 col3" >Set</td>
#       <td id="T_ebcc6_row3_col4" class="data row3 col4" >NA</td>
#       <td id="T_ebcc6_row3_col5" class="data row3 col5" >NA</td>
#     </tr>
#     <tr>
#       <th id="T_ebcc6_level0_row4" class="row_heading level0 row4" >Chicualacuala</th>
#       <td id="T_ebcc6_row4_col0" class="data row4 col0" >NA</td>
#       <td id="T_ebcc6_row4_col1" class="data row4 col1" >Set</td>
#       <td id="T_ebcc6_row4_col2" class="data row4 col2" >NA</td>
#       <td id="T_ebcc6_row4_col3" class="data row4 col3" >NA</td>
#       <td id="T_ebcc6_row4_col4" class="data row4 col4" >Set</td>
#       <td id="T_ebcc6_row4_col5" class="data row4 col5" >Set</td>
#     </tr>
#     <tr>
#       <th id="T_ebcc6_level0_row5" class="row_heading level0 row5" >Chiure</th>
#       <td id="T_ebcc6_row5_col0" class="data row5 col0" >NA</td>
#       <td id="T_ebcc6_row5_col1" class="data row5 col1" >NA</td>
#       <td id="T_ebcc6_row5_col2" class="data row5 col2" >NA</td>
#       <td id="T_ebcc6_row5_col3" class="data row5 col3" >NA</td>
#       <td id="T_ebcc6_row5_col4" class="data row5 col4" >NA</td>
#       <td id="T_ebcc6_row5_col5" class="data row5 col5" >missing so far</td>
#     </tr>
#     <tr>
#       <th id="T_ebcc6_level0_row6" class="row_heading level0 row6" >Guija</th>
#       <td id="T_ebcc6_row6_col0" class="data row6 col0" >NA</td>
#       <td id="T_ebcc6_row6_col1" class="data row6 col1" >NA</td>
#       <td id="T_ebcc6_row6_col2" class="data row6 col2" >NA</td>
#       <td id="T_ebcc6_row6_col3" class="data row6 col3" >Ready</td>
#       <td id="T_ebcc6_row6_col4" class="data row6 col4" >Ready</td>
#       <td id="T_ebcc6_row6_col5" class="data row6 col5" >Set</td>
#     </tr>
#     <tr>
#       <th id="T_ebcc6_level0_row7" class="row_heading level0 row7" >Mabalane</th>
#       <td id="T_ebcc6_row7_col0" class="data row7 col0" >NA</td>
#       <td id="T_ebcc6_row7_col1" class="data row7 col1" >NA</td>
#       <td id="T_ebcc6_row7_col2" class="data row7 col2" >NA</td>
#       <td id="T_ebcc6_row7_col3" class="data row7 col3" >NA</td>
#       <td id="T_ebcc6_row7_col4" class="data row7 col4" >Set</td>
#       <td id="T_ebcc6_row7_col5" class="data row7 col5" >Ready</td>
#     </tr>
#     <tr>
#       <th id="T_ebcc6_level0_row8" class="row_heading level0 row8" >Magude</th>
#       <td id="T_ebcc6_row8_col0" class="data row8 col0" >NA</td>
#       <td id="T_ebcc6_row8_col1" class="data row8 col1" >NA</td>
#       <td id="T_ebcc6_row8_col2" class="data row8 col2" >NA</td>
#       <td id="T_ebcc6_row8_col3" class="data row8 col3" >NA</td>
#       <td id="T_ebcc6_row8_col4" class="data row8 col4" >Set</td>
#       <td id="T_ebcc6_row8_col5" class="data row8 col5" >NA</td>
#     </tr>
#     <tr>
#       <th id="T_ebcc6_level0_row9" class="row_heading level0 row9" >Mapai</th>
#       <td id="T_ebcc6_row9_col0" class="data row9 col0" >Set</td>
#       <td id="T_ebcc6_row9_col1" class="data row9 col1" >Set</td>
#       <td id="T_ebcc6_row9_col2" class="data row9 col2" >Set</td>
#       <td id="T_ebcc6_row9_col3" class="data row9 col3" >NA</td>
#       <td id="T_ebcc6_row9_col4" class="data row9 col4" >Set</td>
#       <td id="T_ebcc6_row9_col5" class="data row9 col5" >NA</td>
#     </tr>
#     <tr>
#       <th id="T_ebcc6_level0_row10" class="row_heading level0 row10" >Marara</th>
#       <td id="T_ebcc6_row10_col0" class="data row10 col0" >NA</td>
#       <td id="T_ebcc6_row10_col1" class="data row10 col1" >NA</td>
#       <td id="T_ebcc6_row10_col2" class="data row10 col2" >Set</td>
#       <td id="T_ebcc6_row10_col3" class="data row10 col3" >missing so far</td>
#       <td id="T_ebcc6_row10_col4" class="data row10 col4" >missing so far</td>
#       <td id="T_ebcc6_row10_col5" class="data row10 col5" >missing so far</td>
#     </tr>
#     <tr>
#       <th id="T_ebcc6_level0_row11" class="row_heading level0 row11" >Massingir</th>
#       <td id="T_ebcc6_row11_col0" class="data row11 col0" >Set</td>
#       <td id="T_ebcc6_row11_col1" class="data row11 col1" >NA</td>
#       <td id="T_ebcc6_row11_col2" class="data row11 col2" >Set</td>
#       <td id="T_ebcc6_row11_col3" class="data row11 col3" >

# %% [markdown]
# **Summary**
#
# R:
#
# - 8 ready states (W2)
# - 9 activations for W1 (Caia, Chibuto, Chicualacuala, Mapai, Marara, Massingir)
# - 7 activations for W2 so far (Chibuto, Chicualacuala, Guija, Mabalane, Mapai, Massingir)
#
# Python:
#
# - 7 ready states (W2)
# - 12 activations for W1 (Changara, Chibuto, Chicualacuala, Mabalane, Mapai, Marara, Massingir)
# - 7 activations for W2 so far (Chibuto, Guija, Mabalane, Massingir)

# %% [markdown]
# ### More detailed comparison

# %%
def compare_R_Python_outcomes(df_r, df_python):
    comp = pd.DataFrame(columns=["W1-Leve", "W1-Moderado", "W1-Severo", "W2-Leve", "W2-Moderado", "W2-Severo"], index = df_python.index)
    for d, row in comp.iterrows():
        for col in comp.columns:
            if df_python.loc[d, col] == 'Set' and df_r.loc[d, col] == 'Set':
                comp.loc[d, col] = 'both set'
            elif df_python.loc[d, col] == 'NA' and df_r.loc[d, col] == 'NA':
                comp.loc[d, col] = 'both NA'
            elif df_python.loc[d, col] == 'Ready' and df_r.loc[d, col] == 'Ready':
                comp.loc[d, col] = 'both ready'
            elif df_python.loc[d, col] == 'Set' and df_r.loc[d, col] == 'NA':
                comp.loc[d, col] = 'P set not R'
            elif df_python.loc[d, col] == 'NA' and df_r.loc[d, col] == 'Set':
                comp.loc[d, col] = 'R set not P'
            elif type(df_python.loc[d, col]) is not str or type(df_r.loc[d, col]) is not str:
                comp.loc[d, col] = 'missing so far'
            else: 
                comp.loc[d, col] = 'not complete'

    colors = {'P set not R': 'darkgreen', 'both set': 'mediumseagreen', 'both NA': 'mediumseagreen', 'both ready': 'mediumseagreen', 'R set not P': 'coral', 'missing so far': 'burlywood', 'not complete': 'burlywood'}
    return comp.style.map(lambda val: 'background-color: {}'.format(colors.get(val,'')))

# %%
compare_R_Python_outcomes(outcomes_R, outcomes)
# Out:
# <style type="text/css">
# #T_0408d_row0_col0, #T_0408d_row0_col3, #T_0408d_row1_col2, #T_0408d_row2_col0, #T_0408d_row2_col1, #T_0408d_row2_col2, #T_0408d_row2_col3, #T_0408d_row3_col1, #T_0408d_row3_col3, #T_0408d_row4_col2, #T_0408d_row4_col3, #T_0408d_row5_col0, #T_0408d_row5_col1, #T_0408d_row5_col2, #T_0408d_row5_col3, #T_0408d_row6_col0, #T_0408d_row6_col1, #T_0408d_row6_col2, #T_0408d_row7_col1, #T_0408d_row7_col2, #T_0408d_row8_col0, #T_0408d_row8_col1, #T_0408d_row8_col2, #T_0408d_row8_col5, #T_0408d_row9_col0, #T_0408d_row9_col2, #T_0408d_row10_col4 {
#   background-color: mediumseagreen;
# }
# #T_0408d_row0_col1, #T_0408d_row0_col2, #T_0408d_row4_col1, #T_0408d_row4_col5, #T_0408d_row10_col0, #T_0408d_row10_col2 {
#   background-color: coral;
# }
# #T_0408d_row0_col4, #T_0408d_row0_col5, #T_0408d_row1_col3, #T_0408d_row1_col4, #T_0408d_row1_col5, #T_0408d_row2_col4, #T_0408d_row2_col5, #T_0408d_row3_col2, #T_0408d_row3_col4, #T_0408d_row4_col4, #T_0408d_row5_col4, #T_0408d_row5_col5, #T_0408d_row6_col3, #T_0408d_row6_col4, #T_0408d_row6_col5, #T_0408d_row7_col4, #T_0408d_row7_col5, #T_0408d_row8_col3, #T_0408d_row8_col4, #T_0408d_row9_col3, #T_0408d_row9_col4, #T_0408d_row9_col5, #T_0408d_row10_col5 {
#   background-color: burlywood;
# }
# #T_0408d_row1_col0, #T_0408d_row1_col1, #T_0408d_row3_col0, #T_0408d_row3_col5, #T_0408d_row4_col0, #T_0408d_row7_col0, #T_0408d_row7_col3, #T_0408d_row9_col1, #T_0408d_row10_col1, #T_0408d_row10_col3 {
#   background-color: darkgreen;
# }
# </style>
# <table id="T_0408d">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_0408d_level0_col0" class="col_heading level0 col0" >W1-Leve</th>
#       <th id="T_0408d_level0_col1" class="col_heading level0 col1" >W1-Moderado</th>
#       <th id="T_0408d_level0_col2" class="col_heading level0 col2" >W1-Severo</th>
#       <th id="T_0408d_level0_col3" class="col_heading level0 col3" >W2-Leve</th>
#       <th id="T_0408d_level0_col4" class="col_heading level0 col4" >W2-Moderado</th>
#       <th id="T_0408d_level0_col5" class="col_heading level0 col5" >W2-Severo</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_0408d_level0_row0" class="row_heading level0 row0" >Caia</th>
#       <td id="T_0408d_row0_col0" class="data row0 col0" >both NA</td>
#       <td id="T_0408d_row0_col1" class="data row0 col1" >R set not P</td>
#       <td id="T_0408d_row0_col2" class="data row0 col2" >R set not P</td>
#       <td id="T_0408d_row0_col3" class="data row0 col3" >both ready</td>
#       <td id="T_0408d_row0_col4" class="data row0 col4" >missing so far</td>
#       <td id="T_0408d_row0_col5" class="data row0 col5" >missing so far</td>
#     </tr>
#     <tr>
#       <th id="T_0408d_level0_row1" class="row_heading level0 row1" >Changara</th>
#       <td id="T_0408d_row1_col0" class="data row1 col0" >P set not R</td>
#       <td id="T_0408d_row1_col1" class="data row1 col1" >P set not R</td>
#       <td id="T_0408d_row1_col2" class="data row1 col2" >both NA</td>
#       <td id="T_0408d_row1_col3" class="data row1 col3" >missing so far</td>
#       <td id="T_0408d_row1_col4" class="data row1 col4" >missing so far</td>
#       <td id="T_0408d_row1_col5" class="data row1 col5" >missing so far</td>
#     </tr>
#     <tr>
#       <th id="T_0408d_level0_row2" class="row_heading level0 row2" >Chemba</th>
#       <td id="T_0408d_row2_col0" class="data row2 col0" >both NA</td>
#       <td id="T_0408d_row2_col1" class="data row2 col1" >both NA</td>
#       <td id="T_0408d_row2_col2" class="data row2 col2" >both NA</td>
#       <td id="T_0408d_row2_col3" class="data row2 col3" >both ready</td>
#       <td id="T_0408d_row2_col4" class="data row2 col4" >not complete</td>
#       <td id="T_0408d_row2_col5" class="data row2 col5" >missing so far</td>
#     </tr>
#     <tr>
#       <th id="T_0408d_level0_row3" class="row_heading level0 row3" >Chibuto</th>
#       <td id="T_0408d_row3_col0" class="data row3 col0" >P set not R</td>
#       <td id="T_0408d_row3_col1" class="data row3 col1" >both set</td>
#       <td id="T_0408d_row3_col2" class="data row3 col2" >missing so far</td>
#       <td id="T_0408d_row3_col3" class="data row3 col3" >both set</td>
#       <td id="T_0408d_row3_col4" class="data row3 col4" >not complete</td>
#       <td id="T_0408d_row3_col5" class="data row3 col5" >P set not R</td>
#     </tr>
#     <tr>
#       <th id="T_0408d_level0_row4" class="row_heading level0 row4" >Chicualacuala</th>
#       <td id="T_0408d_row4_col0" class="data row4 col0" >P set not R</td>
#       <td id="T_0408d_row4_col1" class="data row4 col1" >R set not P</td>
#       <td id="T_0408d_row4_col2" class="data row4 col2" >both NA</td>
#       <td id="T_0408d_row4_col3" class="data row4 col3" >both NA</td>
#       <td id="T_0408d_row4_col4" class="data row4 col4" >missing so far</td>
#       <td id="T_0408d_row4_col5" class="data row4 col5" >R set not P</td>
#     </tr>
#     <tr>
#       <th id="T_0408d_level0_row5" class="row_heading level0 row5" >Chiure</th>
#       <td id="T_0408d_row5_col0" class="data row5 col0" >both NA</td>
#       <td id="T_0408d_row5_col1" class="data row5 col1" >both NA</td>
#       <td id="T_0408d_row5_col2" class="data row5 col2" >both NA</td>
#       <td id="T_0408d_row5_col3" class="data row5 col3" >both NA</td>
#       <td id="T_0408d_row5_col4" class="data row5 col4" >missing so far</td>
#       <td id="T_0408d_row5_col5" class="data row5 col5" >missing so far</td>
#     </tr>
#     <tr>
#       <th id="T_0408d_level0_row6" class="row_heading level0 row6" >Guija</th>
#       <td id="T_0408d_row6_col0" class="data row6 col0" >both NA</td>
#       <td id="T_0408d_row6_col1" class="data row6 col1" >both NA</td>
#       <td id="T_0408d_row6_col2" class="data row6 col2" >both NA</td>
#       <td id="T_0408d_row6_col3" class="data row6 col3" >not complete</td>
#       <td id="T_0408d_row6_col4" class="data row6 col4" >not complete</td>
#       <td id="T_0408d_row6_col5" class="data row6 col5" >missing so far</td>
#     </tr>
#     <tr>
#       <th id="T_0408d_level0_row7" class="row_heading level0 row7" >Mabalane</th>
#       <td id="T_0408d_row7_col0" class="data row7 col0" >P set not R</td>
#       <td id="T_0408d_row7_col1" class="data row7 col1" >both NA</td>
#       <td id="T_0408d_row7_col2" class="data row7 col2" >both NA</td>
#       <td id="T_0408d_row7_col3" class="data row7 col3" >P set not R</td>
#       <td id="T_0408d_row7_col4" class="data row7 col4" >not complete</td>
#       <td id="T_0408d_row7_col5" class="data row7 col5" >not complete</td>
#     </tr>
#     <tr>
#       <th id="T_0408d_level0_row8" class="row_heading level0 row8" >Mapai</th>
#       <td id="T_0408d_row8_col0" class="data row8 col0" >both set</td>
#       <td id="T_0408d_row8_col1" class="data row8 col1" >both set</td>
#       <td id="T_0408d_row8_col2" class="data row8 col2" >both set</td>
#       <td id="T_0408d_row8_col3" class="data row8 col3" >not complete</td>
#       <td id="T_0408d_row8_col4" class="data row8 col4" >not complete</td>
#       <td id="T_0408d_row8_col5" class="data row8 col5" >both NA</td>
#     </tr>
#     <tr>
#       <th id="T_0408d_level0_row9" class="row_heading level0 row9" >Marara</th>
#       <td id="T_0408d_row9_col0" class="data row9 col0" >both NA</td>
#       <td id="T_0408d_row9_col1" class="data row9 col1" >P set not R</td>
#       <td id="T_0408d_row9_col2" class="data row9 col2" >both set</td>
#       <td id="T_0408d_row9_col3" class="data row9 col3" >missing so far</td>
#       <td id="T_0408d_row9_col4" class="data row9 col4" >missing so far</td>
#       <td id="T_0408d_row9_col5" class="data row9 col5" >missing so far</td>
#     </tr>
#     <tr>
#       <th id="T_0408d_level0_row10" class="row_heading level0 row10" >Massingir</th>
#       <td id="T_0408d_row10_col0" class="data row10 col0" >R set not P</td>
#       <td id="T_0408d_row10_col1" class="data row10 col1" >P set not R</td>
#       <td id="T_0408d_row10_col2" class="data row10 col2" >R set not P</td>
#       <td id="T_0408d_row10_col3" class="data row10 col3" >P set not R</td>
#       <td id="T_0408d_row10_col4" class="data row10 col4" >both set</td>
#       <td id="T_0408d_ro

# %% [markdown]
# *Annex: comparison of selected indexes*

# %%
df_merged.type.value_counts()
# Out:
# type
# SPI         162
# DRYSPELL     31
# Name: count, dtype: int64

# %%
ref.Type.value_counts()
# Out:
# Type
# SPI          165
# DRY SPELL     41
# Name: count, dtype: int64

# %%
ref['Index'] = [f"DRYSPELL {i[3:]}" if i[:4] == 'DRY ' else i for i in ref['Index'].values]

# %%
def jaccard_set(list1, list2):
    """Define Jaccard Similarity function for two sets"""
    intersection = len(list(set(list1).intersection(list2)))
    union = (len(list1) + len(list2)) - intersection
    try:
        return float(intersection) / union
    except:
        return 0

# %% [markdown]
# Similarity between Index / Period combinations

# %%
indexes_comp = pd.DataFrame(columns=["W1-Leve", "W1-Moderado", "W1-Severo", "W2-Leve", "W2-Moderado", "W2-Severo"], index = df_merged['district'].sort_values().unique())
for d, r in indexes_comp.iterrows():
    val = []
    for w in df_merged['Window'].unique():
        for c in df_merged['category'].unique():
            python = df_merged[(df_merged['Window']==w) & (df_merged['category']==c) & (df_merged['district']==d)]['index'].unique()
            r = ref[(ref['Windows']==w) & (ref['Category']==c) & (ref['District']==d)]['Index'].unique()
            if len(python) == 0 or len(r) == 0:
                val.append(-1)
            else:
                val.append(round(jaccard_set(python, r), 2))   
    indexes_comp.loc[d] = val

# %%
colors2 = {1: 'darkgreen', 0.5: 'seagreen', 0.33: 'steelblue', 0.25: 'slategrey', 0: 'dimgray', -1: 'burlywood'}
indexes_comp.style.map(lambda val: 'background-color: {}'.format(colors2.get(val,'')))
# Out:
# <style type="text/css">
# #T_deaa4_row0_col0, #T_deaa4_row0_col1, #T_deaa4_row1_col0, #T_deaa4_row2_col1, #T_deaa4_row3_col1, #T_deaa4_row5_col0, #T_deaa4_row5_col1, #T_deaa4_row5_col2, #T_deaa4_row6_col0, #T_deaa4_row6_col1, #T_deaa4_row8_col3, #T_deaa4_row8_col4, #T_deaa4_row9_col0, #T_deaa4_row9_col1, #T_deaa4_row9_col2, #T_deaa4_row10_col3 {
#   background-color: steelblue;
# }
# #T_deaa4_row0_col2, #T_deaa4_row0_col3, #T_deaa4_row1_col1, #T_deaa4_row3_col3, #T_deaa4_row3_col4, #T_deaa4_row5_col3, #T_deaa4_row6_col2, #T_deaa4_row6_col3, #T_deaa4_row6_col4, #T_deaa4_row7_col5, #T_deaa4_row10_col2, #T_deaa4_row10_col4, #T_deaa4_row10_col5 {
#   background-color: dimgray;
# }
# #T_deaa4_row0_col4, #T_deaa4_row0_col5, #T_deaa4_row1_col3, #T_deaa4_row1_col4, #T_deaa4_row1_col5, #T_deaa4_row2_col5, #T_deaa4_row3_col2, #T_deaa4_row4_col4, #T_deaa4_row5_col4, #T_deaa4_row6_col5, #T_deaa4_row9_col3, #T_deaa4_row9_col4, #T_deaa4_row9_col5 {
#   background-color: burlywood;
# }
# #T_deaa4_row1_col2, #T_deaa4_row2_col3, #T_deaa4_row3_col5, #T_deaa4_row4_col1, #T_deaa4_row4_col2, #T_deaa4_row4_col3, #T_deaa4_row7_col0, #T_deaa4_row7_col1, #T_deaa4_row7_col2, #T_deaa4_row8_col1, #T_deaa4_row8_col5, #T_deaa4_row10_col0, #T_deaa4_row10_col1 {
#   background-color: seagreen;
# }
# #T_deaa4_row2_col0, #T_deaa4_row2_col2, #T_deaa4_row2_col4, #T_deaa4_row3_col0, #T_deaa4_row4_col0, #T_deaa4_row4_col5, #T_deaa4_row5_col5, #T_deaa4_row8_col0, #T_deaa4_row8_col2 {
#   background-color: darkgreen;
# }
# #T_deaa4_row7_col3, #T_deaa4_row7_col4 {
#   background-color: slategrey;
# }
# </style>
# <table id="T_deaa4">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_deaa4_level0_col0" class="col_heading level0 col0" >W1-Leve</th>
#       <th id="T_deaa4_level0_col1" class="col_heading level0 col1" >W1-Moderado</th>
#       <th id="T_deaa4_level0_col2" class="col_heading level0 col2" >W1-Severo</th>
#       <th id="T_deaa4_level0_col3" class="col_heading level0 col3" >W2-Leve</th>
#       <th id="T_deaa4_level0_col4" class="col_heading level0 col4" >W2-Moderado</th>
#       <th id="T_deaa4_level0_col5" class="col_heading level0 col5" >W2-Severo</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_deaa4_level0_row0" class="row_heading level0 row0" >Caia</th>
#       <td id="T_deaa4_row0_col0" class="data row0 col0" >0.330000</td>
#       <td id="T_deaa4_row0_col1" class="data row0 col1" >0.330000</td>
#       <td id="T_deaa4_row0_col2" class="data row0 col2" >0.000000</td>
#       <td id="T_deaa4_row0_col3" class="data row0 col3" >0.000000</td>
#       <td id="T_deaa4_row0_col4" class="data row0 col4" >-1</td>
#       <td id="T_deaa4_row0_col5" class="data row0 col5" >-1</td>
#     </tr>
#     <tr>
#       <th id="T_deaa4_level0_row1" class="row_heading level0 row1" >Changara</th>
#       <td id="T_deaa4_row1_col0" class="data row1 col0" >0.330000</td>
#       <td id="T_deaa4_row1_col1" class="data row1 col1" >0.000000</td>
#       <td id="T_deaa4_row1_col2" class="data row1 col2" >0.500000</td>
#       <td id="T_deaa4_row1_col3" class="data row1 col3" >-1</td>
#       <td id="T_deaa4_row1_col4" class="data row1 col4" >-1</td>
#       <td id="T_deaa4_row1_col5" class="data row1 col5" >-1</td>
#     </tr>
#     <tr>
#       <th id="T_deaa4_level0_row2" class="row_heading level0 row2" >Chemba</th>
#       <td id="T_deaa4_row2_col0" class="data row2 col0" >1.000000</td>
#       <td id="T_deaa4_row2_col1" class="data row2 col1" >0.330000</td>
#       <td id="T_deaa4_row2_col2" class="data row2 col2" >1.000000</td>
#       <td id="T_deaa4_row2_col3" class="data row2 col3" >0.500000</td>
#       <td id="T_deaa4_row2_col4" class="data row2 col4" >1.000000</td>
#       <td id="T_deaa4_row2_col5" class="data row2 col5" >-1</td>
#     </tr>
#     <tr>
#       <th id="T_deaa4_level0_row3" class="row_heading level0 row3" >Chibuto</th>
#       <td id="T_deaa4_row3_col0" class="data row3 col0" >1.000000</td>
#       <td id="T_deaa4_row3_col1" class="data row3 col1" >0.330000</td>
#       <td id="T_deaa4_row3_col2" class="data row3 col2" >-1</td>
#       <td id="T_deaa4_row3_col3" class="data row3 col3" >0.000000</td>
#       <td id="T_deaa4_row3_col4" class="data row3 col4" >0.000000</td>
#       <td id="T_deaa4_row3_col5" class="data row3 col5" >0.500000</td>
#     </tr>
#     <tr>
#       <th id="T_deaa4_level0_row4" class="row_heading level0 row4" >Chicualacuala</th>
#       <td id="T_deaa4_row4_col0" class="data row4 col0" >1.000000</td>
#       <td id="T_deaa4_row4_col1" class="data row4 col1" >0.500000</td>
#       <td id="T_deaa4_row4_col2" class="data row4 col2" >0.500000</td>
#       <td id="T_deaa4_row4_col3" class="data row4 col3" >0.500000</td>
#       <td id="T_deaa4_row4_col4" class="data row4 col4" >-1</td>
#       <td id="T_deaa4_row4_col5" class="data row4 col5" >1.000000</td>
#     </tr>
#     <tr>
#       <th id="T_deaa4_level0_row5" class="row_heading level0 row5" >Chiure</th>
#       <td id="T_deaa4_row5_col0" class="data row5 col0" >0.330000</td>
#       <td id="T_deaa4_row5_col1" class="data row5 col1" >0.330000</td>
#       <td id="T_deaa4_row5_col2" class="data row5 col2" >0.330000</td>
#       <td id="T_deaa4_row5_col3" class="data row5 col3" >0.000000</td>
#       <td id="T_deaa4_row5_col4" class="data row5 col4" >-1</td>
#       <td id="T_deaa4_row5_col5" class="data row5 col5" >1.000000</td>
#     </tr>
#     <tr>
#       <th id="T_deaa4_level0_row6" class="row_heading level0 row6" >Guija</th>
#       <td id="T_deaa4_row6_col0" class="data row6 col0" >0.330000</td>
#       <td id="T_deaa4_row6_col1" class="data row6 col1" >0.330000</td>
#       <td id="T_deaa4_row6_col2" class="data row6 col2" >0.000000</td>
#       <td id="T_deaa4_row6_col3" class="data row6 col3" >0.000000</td>
#       <td id="T_deaa4_row6_col4" class="data row6 col4" >0.000000</td>
#       <td id="T_deaa4_row6_col5" class="data row6 col5" >-1</td>
#     </tr>
#     <tr>
#       <th id="T_deaa4_level0_row7" class="row_heading level0 row7" >Mabalane</th>
#       <td id="T_deaa4_row7_col0" class="data row7 col0" >0.500000</td>
#       <td id="T_deaa4_row7_col1" class="data row7 col1" >0.500000</td>
#       <td id="T_deaa4_row7_col2" class="data row7 col2" >0.500000</td>
#       <td id="T_deaa4_row7_col3" class="data row7 col3" >0.250000</td>
#       <td id="T_deaa4_row7_col4" class="data row7 col4" >0.250000</td>
#       <td id="T_deaa4_row7_col5" class="data row7 col5" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_deaa4_level0_row8" class="row_heading level0 row8" >Mapai</th>
#       <td id="T_deaa4_row8_col0" class="data row8 col0" >1.000000</td>
#       <td id="T_deaa4_row8_col1" class="data row8 col1" >0.500000</td>
#       <td id="T_deaa4_row8_col2" class="data row8 col2" >1.000000</td>
#       <td id="T_deaa4_row8_col3" class="data row8 col3" >0.330000</td>
#       <td id="T_deaa4_row8_col4" class="data row8 col4" >0.330000</td>
#       <td id="T_deaa4_row8_col5" class="data row8 col5" >0.500000</td>
#     </tr>
#     <tr>
#       <th id="T_deaa4_level0_row9" class="row_heading level0 row9" >Marara</th>
#       <td id="T_deaa4_row9_col0" class="data row9 col0" >0.330000</td>
#       <td id="T_deaa4_row9_col1" class="data row9 col1" >0.330000</td>
#       <td id="T_deaa4_row9_col2" class="data row9 col2" >0.330000</td>
#       <td id="T_deaa4_row9_col3" class="data row9 col3" >-1</td>
#       <td id="T_deaa4_row9_col4" class="data row9 col4" >-1</td>
#       <td id="T_deaa4_row9_col5" class="data row9 col5" >-1</td>
#     </tr>
#     <tr>
#       <th id="T_deaa4_level0_row10" class="row_heading level0 row10" >Massingir</th>
#       <td id="T_deaa4_row10_col0" class="data row10 col0" >0.500000</td>
#       <td id="T_deaa4_row10_col1" class="data row10 col1" >0.500000</td>
#       <td id="T_deaa4_row10_col2" class="data row10 col2" >0.000000</td>
#       <td id="T_deaa4_row10_col3" class="data row10 col3" >0.330000</td>
#       <td id="T_deaa4_row10_col4" class="data row10 col4" >0.000000</td>
#       <td id="T_deaa4_row10_col5" class="data row10 col5" >0.000000</td>
#     </tr>
#   </tbody>
# </table>

# %%
indexes
# Out:
#                           W1-Leve             W1-Moderado  \
# Caia           [SPI NDJ, SPI DJF]       [SPI JF, SPI DJF]
# Changara        [SPI NDJ, SPI DJ]        [SPI JF, SPI DJ]
# Chemba           [SPI JF, SPI DJ]       [SPI JF, SPI DJF]
# Chibuto        [SPI OND, SPI NDJ]        [SPI ON, SPI DJ]
# Chicualacuala   [SPI NDJ, SPI DJ]  [SPI ND, DRYSPELL NDJ]
# Chiure          [SPI JF, SPI DJF]       [SPI JF, SPI DJF]
# Guija          [SPI OND, SPI NDJ]      [SPI OND, SPI NDJ]
# Mabalane        [SPI OND, SPI DJ]      [SPI OND, SPI NDJ]
# Mapai           [SPI NDJ, SPI DJ]       [SPI OND, SPI DJ]
# Marara         [SPI NDJ, SPI DJF]       [SPI NDJ, SPI DJ]
# Massingir       [SPI OND, SPI ND]       [SPI ON, SPI NDJ]
#
#                                  W1-Severo  \
# Caia                     [SPI NDJ, SPI DJ]
# Changara                [SPI NDJ, SPI DJF]
# Chemba                  [SPI NDJ, SPI DJF]
# Chibuto                                 []
# Chicualacuala        [SPI DJ, DRYSPELL ON]
# Chiure                    [SPI JF, SPI DJ]
# Guija               [SPI ON, DRYSPELL NDJ]
# Mabalane                 [SPI ON, SPI NDJ]
# Mapai                    [SPI OND, SPI ND]
# Marara                   [SPI NDJ, SPI DJ]
# Massingir      [DRYSPELL NDJ, DRYSPELL DJ]
#
#                                             W2-Leve  \
# Caia                                       [SPI MA]
# Changara                              [DRYSPELL MA]
# Chemba                       [SPI MA, DRYSPELL JFM]
# Chibuto                          [SPI JFM, SPI DJF]
# Chicualacuala                             [SPI DJF]
# Chiure         [SPI FMA, DRYSPELL MA, DRYSPELL FMA]
# Guija                             [SPI JF, SPI DJF]
# Mabalane           [SPI JFM, SPI DJF, DRYSPELL DJF]
# Mapai               [SPI JFM, SPI DJF, DRYSPELL JF]
# Marara                               [DRYSPELL FMA]
# Massingir                    [SPI DJF, DRYSPELL JF]
#
#                                       W2-Moderado                    W2-Severo
# Caia                                           []                           []
# Changara                           [DRYSPELL JFM]  [DRYSPELL JFM, DRYSPELL FM]
# Chemba                                   [SPI MA]                           []
# Chibuto                   [SPI JFM, DRYSPELL JFM]            [SPI JF, SPI DJF]
# Chicualacuala                                  []                    [SPI DJF]
# Chiure                                         []                    [SPI FMA]
# Guija                               [DRYSPELL JF]                           []
# Mabalane       [SPI JF, DRYSPELL MA, DRYSPELL JF]       [SPI DJF, DRYSPELL MA]
# Mapai                      [SPI DJF, DRYSPELL JF]                    [SPI DJF]
# Marara                                         []                           []
# Massingir                       [SPI JF, SPI DJF]           [SPI FMA, SPI DJF]

# %%
indexes_R
# Out:
#                           W1-Leve         W1-Moderado          W1-Severo  \
# Caia                     [DRY DJ]   [DRY DJ, SPI DJF]  [DRY DJ, SPI DJF]
# Changara                [SPI DJF]   [DRY DJ, SPI NDJ]          [SPI DJF]
# Chemba         [SPI DJF, SPI NDJ]    [SPI DJ, SPI JF]   [DRY DJ, SPI JF]
# Chibuto                  [SPI ON]  [SPI NDJ, SPI OND]   [SPI DJ, SPI ND]
# Chicualacuala            [SPI DJ]   [SPI DJ, SPI NDJ]           [SPI ND]
# Chiure           [DRY DJ, SPI DJ]   [SPI DJ, SPI DJF]  [DRY DJ, SPI DJF]
# Guija                   [SPI OND]   [SPI ON, SPI OND]  [SPI NDJ, SPI ON]
# Mabalane                [SPI NDJ]           [SPI OND]          [SPI OND]
# Magude           [SPI DJ, SPI ON]            [SPI ON]           [SPI ON]
# Mapai           [SPI ND, SPI OND]   [SPI DJ, SPI NDJ]           [SPI DJ]
# Marara          [DRY JF, SPI NDJ]   [SPI DJ, SPI DJF]   [DRY DJ, SPI DJ]
# Massingir       [SPI ON, SPI OND]            [SPI ND]           [SPI ON]
#
#                          W2-Leve        W2-Moderado          W2-Severo
# Caia                    [SPI MA]           [DRY FM]           [SPI MA]
# Changara                      []                 []                 []
# Chemba                  [SPI MA]           [SPI MA]           [SPI MA]
# Chibuto                [SPI DJF]           [DRY DJ]           [DRY DJ]
# Chicualacuala          [SPI DJF]  [SPI DJF, SPI JF]          [SPI DJF]
# Chiure                 [SPI FMA]           [DRY MA]                 []
# Guija           [DRY FM, SPI JF]   [DRY MA, SPI MA]          [SPI JFM]
# Mabalane                [SPI JF]  [DRY DJ, SPI DJF]   [DRY DJ, SPI JF]
# Magude         [SPI DJF, SPI JF]          [SPI JFM]           [DRY DJ]
# Mapai          [DRY DJ, SPI DJF]          [SPI DJF]  [DRY DJ, SPI DJF]
# Marara                        []                 []                 []
# Massingir               [SPI JF]  [DRY MA, SPI DJF]           [SPI MA]

# %% [markdown]
# Similarity between Index / Period / Issue combinations

# %%
indexes_comp2 = pd.DataFrame(columns=["W1-Leve", "W1-Moderado", "W1-Severo", "W2-Leve", "W2-Moderado", "W2-Severo"], index = df_merged['district'].sort_values().unique())
for d, r in indexes_comp2.iterrows():
    val = []
    for w in df_merged['Window'].unique():
        for c in df_merged['category'].unique():
            python2 = df_merged[(df_merged['Window']==w) & (df_merged['category']==c) & (df_merged['district']==d)].sort_values('index')
            r2 = ref[(ref['Windows']==w) & (ref['Category']==c) & (ref['District']==d)].sort_values('Index')
            if len(python2) == 0 or len(r) == 0:
                val.append(-1)
            else:
                val.append(round(jaccard_set(list(zip(python2['index'].unique(), python2['issue'].unique())), list(zip(r2['Index'].unique(), r2['Month'].unique()))), 2))   
    indexes_comp2.loc[d] = val

# %%
indexes_comp2.style.map(lambda val: 'background-color: {}'.format(colors2.get(val,'')))
# Out:
# <style type="text/css">
# #T_a8d61_row0_col0, #T_a8d61_row8_col4, #T_a8d61_row9_col1, #T_a8d61_row9_col2 {
#   background-color: steelblue;
# }
# #T_a8d61_row0_col1, #T_a8d61_row0_col2, #T_a8d61_row0_col3, #T_a8d61_row1_col0, #T_a8d61_row1_col1, #T_a8d61_row1_col2, #T_a8d61_row1_col3, #T_a8d61_row1_col4, #T_a8d61_row1_col5, #T_a8d61_row2_col0, #T_a8d61_row2_col1, #T_a8d61_row2_col2, #T_a8d61_row2_col3, #T_a8d61_row3_col0, #T_a8d61_row3_col1, #T_a8d61_row3_col3, #T_a8d61_row3_col4, #T_a8d61_row4_col0, #T_a8d61_row4_col3, #T_a8d61_row4_col5, #T_a8d61_row5_col1, #T_a8d61_row5_col3, #T_a8d61_row6_col0, #T_a8d61_row6_col1, #T_a8d61_row6_col2, #T_a8d61_row6_col3, #T_a8d61_row6_col4, #T_a8d61_row7_col3, #T_a8d61_row7_col4, #T_a8d61_row7_col5, #T_a8d61_row8_col3, #T_a8d61_row9_col3, #T_a8d61_row10_col0, #T_a8d61_row10_col1, #T_a8d61_row10_col2, #T_a8d61_row10_col3, #T_a8d61_row10_col4, #T_a8d61_row10_col5 {
#   background-color: dimgray;
# }
# #T_a8d61_row0_col4, #T_a8d61_row0_col5, #T_a8d61_row2_col5, #T_a8d61_row3_col2, #T_a8d61_row4_col4, #T_a8d61_row5_col4, #T_a8d61_row6_col5, #T_a8d61_row9_col4, #T_a8d61_row9_col5 {
#   background-color: burlywood;
# }
# #T_a8d61_row2_col4, #T_a8d61_row3_col5, #T_a8d61_row5_col5, #T_a8d61_row8_col0, #T_a8d61_row8_col2 {
#   background-color: darkgreen;
# }
# #T_a8d61_row4_col1, #T_a8d61_row4_col2, #T_a8d61_row5_col0, #T_a8d61_row5_col2, #T_a8d61_row7_col0, #T_a8d61_row7_col1, #T_a8d61_row7_col2, #T_a8d61_row8_col1, #T_a8d61_row8_col5, #T_a8d61_row9_col0 {
#   background-color: seagreen;
# }
# </style>
# <table id="T_a8d61">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_a8d61_level0_col0" class="col_heading level0 col0" >W1-Leve</th>
#       <th id="T_a8d61_level0_col1" class="col_heading level0 col1" >W1-Moderado</th>
#       <th id="T_a8d61_level0_col2" class="col_heading level0 col2" >W1-Severo</th>
#       <th id="T_a8d61_level0_col3" class="col_heading level0 col3" >W2-Leve</th>
#       <th id="T_a8d61_level0_col4" class="col_heading level0 col4" >W2-Moderado</th>
#       <th id="T_a8d61_level0_col5" class="col_heading level0 col5" >W2-Severo</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_a8d61_level0_row0" class="row_heading level0 row0" >Caia</th>
#       <td id="T_a8d61_row0_col0" class="data row0 col0" >0.330000</td>
#       <td id="T_a8d61_row0_col1" class="data row0 col1" >0.000000</td>
#       <td id="T_a8d61_row0_col2" class="data row0 col2" >0.000000</td>
#       <td id="T_a8d61_row0_col3" class="data row0 col3" >0.000000</td>
#       <td id="T_a8d61_row0_col4" class="data row0 col4" >-1</td>
#       <td id="T_a8d61_row0_col5" class="data row0 col5" >-1</td>
#     </tr>
#     <tr>
#       <th id="T_a8d61_level0_row1" class="row_heading level0 row1" >Changara</th>
#       <td id="T_a8d61_row1_col0" class="data row1 col0" >0.000000</td>
#       <td id="T_a8d61_row1_col1" class="data row1 col1" >0.000000</td>
#       <td id="T_a8d61_row1_col2" class="data row1 col2" >0.000000</td>
#       <td id="T_a8d61_row1_col3" class="data row1 col3" >0.000000</td>
#       <td id="T_a8d61_row1_col4" class="data row1 col4" >0.000000</td>
#       <td id="T_a8d61_row1_col5" class="data row1 col5" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_a8d61_level0_row2" class="row_heading level0 row2" >Chemba</th>
#       <td id="T_a8d61_row2_col0" class="data row2 col0" >0.000000</td>
#       <td id="T_a8d61_row2_col1" class="data row2 col1" >0.000000</td>
#       <td id="T_a8d61_row2_col2" class="data row2 col2" >0.000000</td>
#       <td id="T_a8d61_row2_col3" class="data row2 col3" >0.000000</td>
#       <td id="T_a8d61_row2_col4" class="data row2 col4" >1.000000</td>
#       <td id="T_a8d61_row2_col5" class="data row2 col5" >-1</td>
#     </tr>
#     <tr>
#       <th id="T_a8d61_level0_row3" class="row_heading level0 row3" >Chibuto</th>
#       <td id="T_a8d61_row3_col0" class="data row3 col0" >0.000000</td>
#       <td id="T_a8d61_row3_col1" class="data row3 col1" >0.000000</td>
#       <td id="T_a8d61_row3_col2" class="data row3 col2" >-1</td>
#       <td id="T_a8d61_row3_col3" class="data row3 col3" >0.000000</td>
#       <td id="T_a8d61_row3_col4" class="data row3 col4" >0.000000</td>
#       <td id="T_a8d61_row3_col5" class="data row3 col5" >1.000000</td>
#     </tr>
#     <tr>
#       <th id="T_a8d61_level0_row4" class="row_heading level0 row4" >Chicualacuala</th>
#       <td id="T_a8d61_row4_col0" class="data row4 col0" >0.000000</td>
#       <td id="T_a8d61_row4_col1" class="data row4 col1" >0.500000</td>
#       <td id="T_a8d61_row4_col2" class="data row4 col2" >0.500000</td>
#       <td id="T_a8d61_row4_col3" class="data row4 col3" >0.000000</td>
#       <td id="T_a8d61_row4_col4" class="data row4 col4" >-1</td>
#       <td id="T_a8d61_row4_col5" class="data row4 col5" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_a8d61_level0_row5" class="row_heading level0 row5" >Chiure</th>
#       <td id="T_a8d61_row5_col0" class="data row5 col0" >0.500000</td>
#       <td id="T_a8d61_row5_col1" class="data row5 col1" >0.000000</td>
#       <td id="T_a8d61_row5_col2" class="data row5 col2" >0.500000</td>
#       <td id="T_a8d61_row5_col3" class="data row5 col3" >0.000000</td>
#       <td id="T_a8d61_row5_col4" class="data row5 col4" >-1</td>
#       <td id="T_a8d61_row5_col5" class="data row5 col5" >1.000000</td>
#     </tr>
#     <tr>
#       <th id="T_a8d61_level0_row6" class="row_heading level0 row6" >Guija</th>
#       <td id="T_a8d61_row6_col0" class="data row6 col0" >0.000000</td>
#       <td id="T_a8d61_row6_col1" class="data row6 col1" >0.000000</td>
#       <td id="T_a8d61_row6_col2" class="data row6 col2" >0.000000</td>
#       <td id="T_a8d61_row6_col3" class="data row6 col3" >0.000000</td>
#       <td id="T_a8d61_row6_col4" class="data row6 col4" >0.000000</td>
#       <td id="T_a8d61_row6_col5" class="data row6 col5" >-1</td>
#     </tr>
#     <tr>
#       <th id="T_a8d61_level0_row7" class="row_heading level0 row7" >Mabalane</th>
#       <td id="T_a8d61_row7_col0" class="data row7 col0" >0.500000</td>
#       <td id="T_a8d61_row7_col1" class="data row7 col1" >0.500000</td>
#       <td id="T_a8d61_row7_col2" class="data row7 col2" >0.500000</td>
#       <td id="T_a8d61_row7_col3" class="data row7 col3" >0.000000</td>
#       <td id="T_a8d61_row7_col4" class="data row7 col4" >0.000000</td>
#       <td id="T_a8d61_row7_col5" class="data row7 col5" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_a8d61_level0_row8" class="row_heading level0 row8" >Mapai</th>
#       <td id="T_a8d61_row8_col0" class="data row8 col0" >1.000000</td>
#       <td id="T_a8d61_row8_col1" class="data row8 col1" >0.500000</td>
#       <td id="T_a8d61_row8_col2" class="data row8 col2" >1.000000</td>
#       <td id="T_a8d61_row8_col3" class="data row8 col3" >0.000000</td>
#       <td id="T_a8d61_row8_col4" class="data row8 col4" >0.330000</td>
#       <td id="T_a8d61_row8_col5" class="data row8 col5" >0.500000</td>
#     </tr>
#     <tr>
#       <th id="T_a8d61_level0_row9" class="row_heading level0 row9" >Marara</th>
#       <td id="T_a8d61_row9_col0" class="data row9 col0" >0.500000</td>
#       <td id="T_a8d61_row9_col1" class="data row9 col1" >0.330000</td>
#       <td id="T_a8d61_row9_col2" class="data row9 col2" >0.330000</td>
#       <td id="T_a8d61_row9_col3" class="data row9 col3" >0.000000</td>
#       <td id="T_a8d61_row9_col4" class="data row9 col4" >-1</td>
#       <td id="T_a8d61_row9_col5" class="data row9 col5" >-1</td>
#     </tr>
#     <tr>
#       <th id="T_a8d61_level0_row10" class="row_heading level0 row10" >Massingir</th>
#       <td id="T_a8d61_row10_col0" class="data row10 col0" >0.000000</td>
#       <td id="T_a8d61_row10_col1" class="data row10 col1" >0.000000</td>
#       <td id="T_a8d61_row10_col2" class="data row10 col2" >0.000000</td>
#       <td id="T_a8d61_row10_col3" class="data row10 col3" >0.000000</td>
#       <td id="T_a8d61_row10_col4" class="data row10 col4" >0.000000</td>
#       <td id="T_a8d61_row10_col5" class="data row10 col5" >0.000000</td>
#     </tr>
#   </tbody>
# </table>
